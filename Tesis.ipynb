# %%
import pandas as pd
import matplotlib.pyplot as plt
import matplotlib.image as image
import numpy as np

ARCHIVO = pd.read_excel("Graficas.xlsx")
ARCHIVO.describe()
# Out:
#        ValT EEA  T Sa vs Sd  DB2 Sa vs Sd "Sa"  DB2 Sa vs Sd "Sd"  \
# count  4.000000  101.000000         101.000000         101.000000
# mean   1.290739    2.500000           0.280645         267.798676
# std    1.625453    1.465009           0.217812         146.670771
# min    0.307000    0.000000           0.069192           0.000000
# 25%    0.443500    1.250000           0.123008         144.434930
# 50%    0.567978    2.500000           0.186000         288.869861
# 75%    1.415217    3.750000           0.372000         429.838353
# max    3.720000    5.000000           0.718750         429.838353
#
#        DB2 Sd (T*)  DB2 Sa (T*)  DB2 Sa vs Sd "Sd" reducido  \
# count    13.000000    13.000000                   71.000000
# mean     74.892308     0.332389                  199.949632
# std      17.303683     0.076798                  122.489572
# min      50.000000     0.221911                    0.000000
# 25%      62.000000     0.275170                  101.104451
# ...

# %%
ARCHIVO.columns
# Out:
# Index(['T EEA', 'Sa EEA', 'T EEA.1', 'ValT EEA', 'VDMC C', 'VDMC MR',
#        'VDMC MI', 'Push D', 'Push V', 'BL D', 'BL V', 'T Sa vs Sd',
#        'DB2 Sa vs Sd "Sa"', 'DB2 Sa vs Sd "Sd"', 'DB2 Sd (T*)', 'DB2 Sa (T*)',
#        'DB2 Sa vs Sd "Sd" reducido', 'DB2 Sa vs Sd "Sa" reducido',
#        'DB2 Sd diagrama capacidad', 'DB2 Sa diagrama capacidad',
#        'Nivel de desempeño', 'DB2 Sd', 'DB2 Sa', 'PushFX mm', 'PushFX V',
#        'PushF_X mm', 'PushF_X V', 'PushDX mm', 'PushDX V', 'PushF_D mm',
#        'PushD_X V', 'VManderCdef', 'VManderCesf', 'VManderNCdef',
#        'VManderNCesf', 'CManderCdef', 'CManderCesf', 'CManderNCdef',
#        'CManderNCesf', 'MManderCdef', 'MManderCesf', 'MManderNCdef',
#        'MManderNCesf', 'Acerodef', 'Aceroesf', 'DB1 Sa vs Sd "Sa"',
#        'DB1 Sa vs Sd "Sd"', 'DB1 Sd (T*)', 'DB1 Sa (T*)',
#        'DB1 Sa vs Sd "Sd" reducido', 'DB1 Sa vs Sd "Sa" reducido',
#        'DB1 Sd diagrama capacidad', 'DB1 Sa diagrama capacidad', 'DB1 Sd',
# ...

# %%
ARCHIVO['T EEA'][1::]
# Out:
# 1      0.05
# 2       0.1
# 3      0.15
# 4       0.2
# 5      0.25
#        ...
# 388     NaN
# 389     NaN
# 390     NaN
# 391     NaN
# 392     NaN
# Name: T EEA, Length: 392, dtype: object

# %% [markdown]
# #Espectro elástico de aceleraciones

# %%
plt.plot(ARCHIVO['T EEA'][1::], ARCHIVO['Sa EEA'][1::], color = "black", label = "Acceleration response spectrum")
plt.axvline(x = ARCHIVO['ValT EEA'][2], ymin = 0, ymax = 0.95, color = "gray",label = r"Period in X direction = {:.2f} $[s]$ ".format(ARCHIVO['ValT EEA'][2]), ls="-.")
plt.axvline(x = ARCHIVO['ValT EEA'][3], ymin = 0, ymax = 0.95, color = "gray",label = r"Period in Y direction = {:.2f} $[s]$ ".format(ARCHIVO['ValT EEA'][3]), ls="--")
plt.axvline(x = ARCHIVO['ValT EEA'][0], ymin = 0, ymax = 0.95, color = "dimgray",label = r"Short Periods = {:.2f} $[s]$ ".format(ARCHIVO['ValT EEA'][0]), ls="-")
plt.axvline(x = ARCHIVO['ValT EEA'][1], ymin = 0, ymax = 0.12, color = "lightgray",label = r"Long Periods = {:.2f} $[s]$ ".format(ARCHIVO['ValT EEA'][1]), ls = "-")
plt.xlim(0, 5)
plt.legend(loc='upper right')
plt.xlabel(r'Period $[s]$')
plt.ylabel(r'Acceleration $[g]$')
# plt.title(r"Elastic Spectrum of Design Accelerations as Fraction of $g$")
ARCHIVO['ValT EEA'][0]
plt.savefig(fname="espectroaceleraciones.pdf", dpi=500, format="pdf")
plt.savefig(fname="espectroaceleraciones.pdf", dpi=500, format="png")

# %% [markdown]
# #Modelo de mander para vigas

# %%
c = ARCHIVO['CManderCdef']
c[c.last_valid_index()]
# Out:
# 0.02035124208026694

# %%
dCC = ARCHIVO['CManderCdef']
dCNC = ARCHIVO['CManderNCdef']
dVC = ARCHIVO['VManderCdef']
dVNC = ARCHIVO['VManderNCdef']
dWC = ARCHIVO['MManderCdef']
dWNC = ARCHIVO['MManderNCdef']
dS = ARCHIVO['Acerodef']

plt.plot(dCC/dCC[dCC.last_valid_index()], ARCHIVO['CManderCesf']/28, color = "silver", label = "Confined Columns")
plt.plot(dCNC/dCNC[dCNC.last_valid_index()], ARCHIVO['CManderNCesf']/28, color = "silver", ls="-.", label="Unconfined Columns")
plt.plot(dVC/dVC[dVC.last_valid_index()], ARCHIVO['VManderCesf']/21, color = "black", label = "Confined Beams")
plt.plot(dVNC/dVNC[dVNC.last_valid_index()], ARCHIVO['VManderNCesf']/21, color = "black", ls="-.", label="Unconfined Beams")
plt.plot(dWC/dWC[dWC.last_valid_index()], ARCHIVO['MManderCesf']/28, color = "dimgray", label = "Confined Walls")
plt.plot(dWNC/dWNC[dWNC.last_valid_index()], ARCHIVO['MManderNCesf']/28, color = "dimgray", ls="-.", label="Unconfined Walls")
plt.plot(dS/dS[dS.last_valid_index()], ARCHIVO['Aceroesf']/420, color = "dimgray", ls=":", label="Rebar")
#plt.axhline(y = 35.91, xmin = 0, xmax = 0.0091/0.03, color = "gray", ls="--")
#plt.axvline(x = 0.0091, ymin = 0, ymax = 35.91/40, color = "gray", ls="--")
plt.xlim(-1, 1)
plt.ylim(-50/28, 50/28)
plt.legend(loc=(0.03, 0.55), ncol = 1, prop={'size': 7})
plt.xlabel(r'Normalized Strain', fontsize=11)
plt.ylabel(r'Normalized Stress', fontsize=11)
plt.title(r"Stress-Strain normalized curves", pad=11, fontsize=13)
#plt.xticks([0.0091], ['ecc'])
#plt.xticks([0, 0.005, 0.01, 0.015, 0.02, 0.025, 0.03])
#plt.yticks([-0.2, 0, 0.2, 0.4, 0.6, 0.8, 1])
plt.axhline(y=0, color='black', ls="-")
plt.axvline(x=0, color='black', ls="-")
plt.grid(True, which='both')
plt.savefig(fname="concretoconf.pdf", dpi=500, format="pdf")

# %%
plt.plot(ARCHIVO['CManderCdef'], ARCHIVO['CManderCesf'], color = "silver", label = "Confined Columns")
plt.plot(ARCHIVO['CManderNCdef'], ARCHIVO['CManderNCesf'], color = "silver", ls="-.", label="Unconfined Columns")
plt.plot(ARCHIVO['VManderCdef'], ARCHIVO['VManderCesf'], color = "black", label = "Confined Beams")
plt.plot(ARCHIVO['VManderNCdef'], ARCHIVO['VManderNCesf'], color = "black", ls="-.", label="Unconfined Beams")
plt.plot(ARCHIVO['MManderCdef'], ARCHIVO['MManderCesf'], color = "dimgray", label = "Confined Walls")
plt.plot(ARCHIVO['MManderNCdef'], ARCHIVO['MManderNCesf'], color = "dimgray", ls="-.", label="Unconfined Walls")
#plt.axhline(y = 35.91, xmin = 0, xmax = 0.0091/0.03, color = "gray", ls="--")
#plt.axvline(x = 0.0091, ymin = 0, ymax = 35.91/40, color = "gray", ls="--")
plt.xlim(-0.002, 0.0301)
plt.ylim(-5, 50)
plt.legend(loc=(0.25, 0.15), ncol = 2, prop={'size': 8})
plt.xlabel(r'Strain$[mm/mm]$', fontsize=11)
plt.ylabel(r'Stress $[MPa]$', fontsize=11)
plt.title(r"Stress-Strain curve of concrete in compression", pad=11, fontsize=13)
#plt.xticks([0.0091], ['ecc'])
plt.xticks([0, 0.005, 0.01, 0.015, 0.02, 0.025, 0.03])
plt.yticks([-5, 0, 10, 20, 30, 40, 50])
plt.axhline(y=0, color='black', ls="-")
plt.axvline(x=0, color='black', ls="-")
plt.grid(True, which='both')
plt.savefig(fname="concretoconf.pdf", dpi=500, format="pdf")

# %% [markdown]
# #Modelo del Acero

# %%
plt.plot(ARCHIVO['Acerodef'], ARCHIVO['Aceroesf'], color = "dimgray")
plt.xlim(-0.08, 0.08)
plt.ylim(-700, 700)
plt.legend(loc='lower right')
plt.ylabel(r'Stress $[MPa]$')
plt.xlabel(r'Strain $[mm/mm]$')
plt.title(r"Steel stress-strain curve")
plt.axhline(y=0, color='black', ls="-")
plt.axvline(x=0, color='black', ls="-")
plt.grid(True, which='both')
plt.savefig(fname="esfdefacero.pdf", dpi=500, format="pdf")
# Out:
# No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.

# %% [markdown]
# #Pushover fuerzas en 2 direcciones

# %%
plt.plot(ARCHIVO['PushFX mm'], ARCHIVO['PushFX V'], color = "black", label = "Pushover X direction")
plt.plot(ARCHIVO['PushF_X mm'][:-10:], ARCHIVO['PushF_X V'][:-10:], color = "black", label = "Pushover -X direction", ls="-.")
plt.xlim(0, 700)
plt.ylim(0, 1100)
plt.legend(loc='lower right')
plt.ylabel(r'Displacement $[mm]$')
plt.xlabel(r'Force $[kN]$')
plt.title(r"Pushover Curve FBD")
plt.savefig(fname="pushoverporfuerzas.pdf", dpi=500, format="pdf")

# %% [markdown]
# #Diagramas momento curvatura

# %%
plt.plot(ARCHIVO['VDMC C'][1::], ARCHIVO['VDMC MR'][1::], color = "black", label = "Real Diagram")
plt.plot(ARCHIVO['VDMC C'][1::], ARCHIVO['VDMC MI'][1::], color = "black", label = "Idealized Diagram ", ls="-.")
plt.xlim(0)
plt.ylim(0, 80)
plt.legend(loc='lower right')
plt.xlabel(r'Curvature $[1/mm]$')
plt.ylabel(r'Moment $[kN.m]$')
plt.title(r"Moment-Curvature Diagram in Beam 2#6-3#4")
plt.savefig(fname="momentocurvatura.pdf", dpi=500, format="pdf")

# %%
plt.plot(ARCHIVO['CDMC C'][1::], ARCHIVO['CDMC MR'][1::], color = "black", label = "Real Diagram")
plt.plot(ARCHIVO['CDMC C'][1::], ARCHIVO['CDMC MI'][1::], color = "black", label = "Idealized Diagram ", ls="-.")
plt.xlim(0)
plt.ylim(0, 500)
plt.legend(loc='lower right')
plt.xlabel(r'Curvature $[1/mm]$')
plt.ylabel(r'Moment $[kN.m]$')
plt.title(r"Moment-Curvature Diagram in Column C2'")
plt.xticks([0, 0.00005, 0.0001, 0.00015, 0.0002])
plt.savefig(fname="momentocurvaturacol.pdf", dpi=500, format="pdf")

# %%
plt.plot(ARCHIVO['MDMC C'][1::], ARCHIVO['MDMC MR'][1::], color = "black", label = "Real Diagram")
plt.plot(ARCHIVO['MDMC C'][1::], ARCHIVO['MDMC MI'][1::], color = "black", label = "Idealized Diagram ", ls="-.")
plt.xlim(0)
plt.ylim(0, 4000)
plt.legend(loc='lower right')
plt.xlabel(r'Curvature $[1/mm]$')
plt.ylabel(r'Moment $[kN.m]$')
plt.title(r"Moment-Curvature Diagram in Wall M2-2'")
plt.savefig(fname="momentocurvaturamuro.pdf", dpi=500, format="pdf")

# %% [markdown]
# #Pushover Bilineal

# %%
plt.plot(ARCHIVO['Push D'][2::], ARCHIVO['Push V'][2::], color = "black", label = "Real Diagram")
plt.plot(ARCHIVO['BL D'][2::], ARCHIVO['BL V'][2::], color = "black", label = "Bilineal Diagram", ls="-.")
plt.xlim(0)
plt.ylim(0, 700)
plt.legend(loc='lower right')
plt.xlabel(r'Displacement $[mm]$')
plt.ylabel(r'Force $[kN]$')
plt.title(r"Real Pushover vs Bilineal Pushover ")
#Dejar imagen del pórtico para el último estado (una dirección)
plt.savefig(fname="pushoverrealbilineal.pdf", dpi=500, format="pdf")

# %% [markdown]
# #Método N2 FB1

# %%
d1, = plt.plot(ARCHIVO['FB1 Sa vs Sd "Sd"'], ARCHIVO['FB1 Sa vs Sd "Sa"'], color = "black", label = "Elastic response spectrum")
d2, = plt.plot(ARCHIVO['FB1 Sa vs Sd "Sd" reducido'], ARCHIVO['FB1 Sa vs Sd "Sa" reducido'], color = "gray", label = "Inelastic design spectrum")
plt.plot(ARCHIVO['FB1 Sd (T*)'], ARCHIVO['FB1 Sa (T*)'], color = "lightgrey", ls="-.")
d3, = plt.plot(ARCHIVO['FB1 Sd diagrama capacidad'], ARCHIVO['FB1 Sa diagrama capacidad'], color = "gray", label = "Capacity diagram SDOF")
plt.xlim(0, 400)
plt.ylim(0, 0.8)
plt.xlabel(r'Displacement $[mm]$')
plt.ylabel(r'Acceleration $[g]$')
xdes=104
ydes=0.343
plt.title(r"FBD N2 Method [X]")
plt.axvline(x = xdes, ymin = 0, ymax = 0.486/0.8, color = "silver", ls="-.")
IO, = plt.plot(ARCHIVO['FB1 Sd'][0],ARCHIVO['FB1 Sa'][0],'h', markersize = 7, color="gray", label= ARCHIVO['Nivel de desempeño'][0]) 
LS, = plt.plot(ARCHIVO['FB1 Sd'][1],ARCHIVO['FB1 Sa'][1],'P', markersize = 7, color="gray", label= ARCHIVO['Nivel de desempeño'][1]) 
CP, = plt.plot(ARCHIVO['FB1 Sd'][2],ARCHIVO['FB1 Sa'][2],'v', markersize = 7, color="gray", label= ARCHIVO['Nivel de desempeño'][2]) 
extra, = plt.plot([], [], ' ', label="Extra label on the legend")
#Añadir cuadrado con desempeño/LS
puntodesempeño, = plt.plot(xdes,ydes,'yo', markersize = 6, color="silver", label= "Performance point") 
legend1 = plt.legend(handles=[IO, LS, CP], loc=(0.49, 0.58), ncol = 3)
plt.gca().add_artist(legend1)
plt.legend(handles=[d1, d2, d3, puntodesempeño], loc='upper right')
xdes/ARCHIVO['FB1 Sd'][1]
#im = image.imread('PushoverFuerzasPDX.jpg')
#plt.imshow(im, aspect='auto', extent=(270, 399, 0.01, 0.45), zorder=10)
plt.savefig(fname="n2FX.pdf", dpi=500, format="pdf")
# Out:
# C:\Users\Juan\AppData\Local\Temp\ipykernel_8124\2253186734.py:18: UserWarning: color is redundantly defined by the 'color' keyword argument and the fmt string "yo" (-> color='y'). The keyword argument will take precedence.
#   puntodesempeño, = plt.plot(xdes,ydes,'yo', markersize = 6, color="silver", label= "Performance point")

# %% [markdown]
# #Método N2 FB2

# %%
d1, = plt.plot(ARCHIVO['FB1 Sa vs Sd "Sd"'], ARCHIVO['FB1 Sa vs Sd "Sa"'], color = "black", label = "Elastic response spectrum")
d2, = plt.plot(ARCHIVO['FB1 Sa vs Sd "Sd" reducido'], ARCHIVO['FB1 Sa vs Sd "Sa" reducido'], color = "gray", label = "Inelastic design spectrum")
d12, = plt.plot(ARCHIVO['FB2 Sa vs Sd "Sd"'], ARCHIVO['FB2 Sa vs Sd "Sa"'], color = "black", label = "Elastic response spectrum")
d22, = plt.plot(ARCHIVO['FB2 Sa vs Sd "Sd" reducido'], ARCHIVO['FB2 Sa vs Sd "Sa" reducido'], color = "gray", label = "Inelastic design spectrum")
plt.plot(ARCHIVO['FB1 Sd (T*)'], ARCHIVO['FB1 Sa (T*)'], color = "lightgrey", ls="-.")
plt.plot(ARCHIVO['FB2 Sd (T*)'], ARCHIVO['FB2 Sa (T*)'], color = "lightgray", ls="-.")
d3, = plt.plot(ARCHIVO['FB1 Sd diagrama capacidad'], ARCHIVO['FB1 Sa diagrama capacidad'], color = "gray", label = "Capacity diagram SDOF")
d32, = plt.plot(ARCHIVO['FB2 Sd diagrama capacidad'], ARCHIVO['FB2 Sa diagrama capacidad'], color = "gray", label = "Diagrama capacidad SDOF")
plt.xlim(0, 400)
plt.ylim(0, 0.8)
plt.xlabel(r'Displacement $[mm]$')
plt.ylabel(r'Acceleration $[g]$')
xdes=104
ydes=0.343
xdes2=113
ydes2=0.276
plt.axvline(x = xdes, ymin = 0, ymax = 0.486/0.8, color = "silver", ls="-.")
IO2, = plt.plot(ARCHIVO['FB2 Sd'][0],ARCHIVO['FB2 Sa'][0],'h', markersize = 7, color="gray", label= ARCHIVO['Nivel de desempeño'][0]) 
LS2, = plt.plot(ARCHIVO['FB2 Sd'][1],ARCHIVO['FB2 Sa'][1],'P', markersize = 7, color="gray", label= ARCHIVO['Nivel de desempeño'][1]) 
CP2, = plt.plot(ARCHIVO['FB2 Sd'][2],ARCHIVO['FB2 Sa'][2],'v', markersize = 7, color="gray", label= ARCHIVO['Nivel de desempeño'][2]) 
plt.title(r"FBD N2 Method [X]")
plt.axvline(x = xdes, ymin = 0, ymax = 0.486/0.8, color = "silver", ls="-.")
plt.axvline(x = xdes2, ymin = 0, ymax = 0.486/0.8, color = "silver", ls="-.")
IO, = plt.plot(ARCHIVO['FB1 Sd'][0],ARCHIVO['FB1 Sa'][0],'h', markersize = 7, color="gray", label= ARCHIVO['Nivel de desempeño'][0]) 
LS, = plt.plot(ARCHIVO['FB1 Sd'][1],ARCHIVO['FB1 Sa'][1],'P', markersize = 7, color="gray", label= ARCHIVO['Nivel de desempeño'][1]) 
CP, = plt.plot(ARCHIVO['FB1 Sd'][2],ARCHIVO['FB1 Sa'][2],'v', markersize = 7, color="gray", label= ARCHIVO['Nivel de desempeño'][2]) 
extra, = plt.plot([], [], ' ', label="Extra label on the legend")
#Añadir cuadrado con desempeño/LS
puntodesempeño, = plt.plot(xdes,ydes,'yo', markersize = 6, color="silver", label= "Performance point") 
puntodesempeño2, = plt.plot(xdes2,ydes2,'yo', markersize = 6, color="silver", label= "Performance point") 
legend1 = plt.legend(handles=[IO, LS, CP], loc=(0.49, 0.58), ncol = 3)
plt.gca().add_artist(legend1)
plt.legend(handles=[d1, d2, d3, puntodesempeño], loc='upper right')
xdes/ARCHIVO['FB1 Sd'][1]
#im = image.imread('PushoverFuerzasPDX.jpg')
#plt.imshow(im, aspect='auto', extent=(270, 399, 0.01, 0.45), zorder=10)
plt.savefig(fname="n2FX.pdf", dpi=500, format="pdf")
# Out:
# C:\Users\Juan\AppData\Local\Temp\ipykernel_8124\3412249940.py:29: UserWarning: color is redundantly defined by the 'color' keyword argument and the fmt string "yo" (-> color='y'). The keyword argument will take precedence.
#   puntodesempeño, = plt.plot(xdes,ydes,'yo', markersize = 6, color="silver", label= "Performance point")
# C:\Users\Juan\AppData\Local\Temp\ipykernel_8124\3412249940.py:30: UserWarning: color is redundantly defined by the 'color' keyword argument and the fmt string "yo" (-> color='y'). The keyword argument will take precedence.
#   puntodesempeño2, = plt.plot(xdes2,ydes2,'yo', markersize = 6, color="silver", label= "Performance point")

# %%
d1, = plt.plot(ARCHIVO['FB2 Sa vs Sd "Sd"'], ARCHIVO['FB2 Sa vs Sd "Sa"'], color = "black", label = "Elastic response spectrum")
d2, = plt.plot(ARCHIVO['FB2 Sa vs Sd "Sd" reducido'], ARCHIVO['FB2 Sa vs Sd "Sa" reducido'], color = "gray", label = "Inelastic design spectrum")
plt.plot(ARCHIVO['FB2 Sd (T*)'], ARCHIVO['FB2 Sa (T*)'], color = "lightgrey", ls="-.")
d3, = plt.plot(ARCHIVO['FB2 Sd diagrama capacidad'], ARCHIVO['FB2 Sa diagrama capacidad'], color = "gray", label = "Diagrama capacidad SDOF")
plt.xlim(0, 400)
plt.ylim(0, 0.8)
plt.xlabel(r'Displacement $[mm]$')
plt.ylabel(r'Acceleration $[g]$')
xdes=113
ydes=0.276
plt.title(r"FBD N2 Method [-X]")
plt.axvline(x = xdes, ymin = 0, ymax = 0.486/0.8, color = "silver", ls="-.")
IO, = plt.plot(ARCHIVO['FB2 Sd'][0],ARCHIVO['FB2 Sa'][0],'h', markersize = 7, color="gray", label= ARCHIVO['Nivel de desempeño'][0]) 
LS, = plt.plot(ARCHIVO['FB2 Sd'][1],ARCHIVO['FB2 Sa'][1],'P', markersize = 7, color="gray", label= ARCHIVO['Nivel de desempeño'][1]) 
CP, = plt.plot(ARCHIVO['FB2 Sd'][2],ARCHIVO['FB2 Sa'][2],'v', markersize = 7, color="gray", label= ARCHIVO['Nivel de desempeño'][2]) 
extra, = plt.plot([], [], ' ', label="Extra label on the legend")
#Añadir cuadrado con desempeño/LS
puntodesempeño, = plt.plot(xdes,ydes,'yo', markersize = 6, color="silver", label= "Performance point") 
legend1 = plt.legend(handles=[IO, LS, CP], loc=(0.49, 0.58), ncol = 3)
plt.gca().add_artist(legend1)
plt.legend(handles=[d1, d2, d3, puntodesempeño], loc='upper right')
xdes/ARCHIVO['FB2 Sd'][1]
#im = image.imread('PushoverFuerzasPD-X.jpg')
#plt.imshow(im, aspect='auto', extent=(270, 399, 0.01, 0.45), zorder=10)
plt.savefig(fname="n2F-X.pdf", dpi=500, format="pdf")
# Out:
# C:\Users\Juan\AppData\Local\Temp\ipykernel_8124\1974427966.py:18: UserWarning: color is redundantly defined by the 'color' keyword argument and the fmt string "yo" (-> color='y'). The keyword argument will take precedence.
#   puntodesempeño, = plt.plot(xdes,ydes,'yo', markersize = 6, color="silver", label= "Performance point")

# %% [markdown]
# #Método N2 DB1

# %%
d1, = plt.plot(ARCHIVO['DB1 Sa vs Sd "Sd"'], ARCHIVO['DB1 Sa vs Sd "Sa"'], color = "black", label = "Elastic response spectrum")
d2, = plt.plot(ARCHIVO['DB1 Sa vs Sd "Sd" reducido'], ARCHIVO['DB1 Sa vs Sd "Sa" reducido'], color = "gray", label = "Inelastic design spectrum")
plt.plot(ARCHIVO['DB1 Sd (T*)'], ARCHIVO['DB1 Sa (T*)'], color = "lightgrey", ls="-.")
d3, = plt.plot(ARCHIVO['DB1 Sd diagrama capacidad'], ARCHIVO['DB1 Sa diagrama capacidad'], color = "gray", label = "Capacity diagram SDOF")
plt.xlim(0, 400)
plt.ylim(0, 0.8)
plt.xlabel(r'Displacement $[mm]$')
plt.ylabel(r'Acceleration $[g]$')
xdes=109
ydes=0.2868
plt.title(r"DBD N2 Method [X]")
plt.axvline(x = xdes, ymin = 0, ymax = 0.486/0.8, color = "silver", ls="-.")
IO, = plt.plot(ARCHIVO['DB1 Sd'][0],ARCHIVO['DB1 Sa'][0],'h', markersize = 7, color="gray", label= ARCHIVO['Nivel de desempeño'][0]) 
LS, = plt.plot(ARCHIVO['DB1 Sd'][1],ARCHIVO['DB1 Sa'][1],'P', markersize = 7, color="gray", label= ARCHIVO['Nivel de desempeño'][1]) 
CP, = plt.plot(ARCHIVO['DB1 Sd'][2],ARCHIVO['DB1 Sa'][2],'v', markersize = 7, color="gray", label= ARCHIVO['Nivel de desempeño'][2]) 
extra, = plt.plot([], [], ' ', label="Extra label on the legend")
#Añadir cuadrado con desempeño/LS
puntodesempeño, = plt.plot(xdes,ydes,'yo', markersize = 6, color="silver", label= "Performance point") 
legend1 = plt.legend(handles=[IO, LS, CP], loc=(0.49, 0.58), ncol = 3)
plt.gca().add_artist(legend1)
plt.legend(handles=[d1, d2, d3, puntodesempeño], loc='upper right')
xdes/ARCHIVO['DB1 Sd'][1]
#im = image.imread('PushoverDesplazamientosPDX.jpg')
#plt.imshow(im, aspect='auto', extent=(270, 399, 0.01, 0.45), zorder=10)
plt.savefig(fname="n2DX.pdf", dpi=500, format="pdf")
# Out:
# C:\Users\Juan\AppData\Local\Temp\ipykernel_8124\652745736.py:18: UserWarning: color is redundantly defined by the 'color' keyword argument and the fmt string "yo" (-> color='y'). The keyword argument will take precedence.
#   puntodesempeño, = plt.plot(xdes,ydes,'yo', markersize = 6, color="silver", label= "Performance point")

# %% [markdown]
# #Método N2 DB

# %%
d1, = plt.plot(ARCHIVO['DB2 Sa vs Sd "Sd"'], ARCHIVO['DB2 Sa vs Sd "Sa"'], color = "black", label = "Elastic response spectrum")
d2, = plt.plot(ARCHIVO['DB2 Sa vs Sd "Sd" reducido'], ARCHIVO['DB2 Sa vs Sd "Sa" reducido'], color = "gray", label = "Inelastic design spectrum")
plt.plot(ARCHIVO['DB2 Sd (T*)'], ARCHIVO['DB2 Sa (T*)'], color = "lightgrey", ls="-.")
d3, = plt.plot(ARCHIVO['DB2 Sd diagrama capacidad'], ARCHIVO['DB2 Sa diagrama capacidad'], color = "gray", label = "Capacity diagram SDOF")
plt.xlim(0, 400)
plt.ylim(0, 0.8)
plt.xlabel(r'Displacement $[mm]$')
plt.ylabel(r'Acceleration $[g]$')
xdes=109.6
ydes=0.223
plt.title(r"DBD N2 Method [-X]")
plt.axvline(x = xdes, ymin = 0, ymax = 0.486/0.8, color = "silver", ls="-.")
IO, = plt.plot(ARCHIVO['DB2 Sd'][0],ARCHIVO['DB2 Sa'][0],'h', markersize = 7, color="gray", label= ARCHIVO['Nivel de desempeño'][0]) 
LS, = plt.plot(ARCHIVO['DB2 Sd'][1],ARCHIVO['DB2 Sa'][1],'P', markersize = 7, color="gray", label= ARCHIVO['Nivel de desempeño'][1]) 
CP, = plt.plot(ARCHIVO['DB2 Sd'][2],ARCHIVO['DB2 Sa'][2],'v', markersize = 7, color="gray", label= ARCHIVO['Nivel de desempeño'][2]) 
extra, = plt.plot([], [], ' ', label="Extra label on the legend")
#Añadir cuadrado con desempeño/LS
puntodesempeño, = plt.plot(xdes,ydes,'yo', markersize = 6, color="slategray", label= "Performance point") 
legend1 = plt.legend(handles=[IO, LS, CP], loc=(0.49, 0.58), ncol = 3)
plt.gca().add_artist(legend1)
plt.legend(handles=[d1, d2, d3, puntodesempeño], loc='upper right')
xdes/ARCHIVO['DB2 Sd'][1]
#im = image.imread('PushoverDesplazamientosPD-X.jpg')
#plt.imshow(im, aspect='auto', extent=(270, 399, 0.01, 0.45), zorder=10)
plt.savefig(fname="n2D-X.pdf", dpi=500, format="pdf")
# Out:
# C:\Users\Juan\AppData\Local\Temp\ipykernel_8124\1219745876.py:18: UserWarning: color is redundantly defined by the 'color' keyword argument and the fmt string "yo" (-> color='y'). The keyword argument will take precedence.
#   puntodesempeño, = plt.plot(xdes,ydes,'yo', markersize = 6, color="slategray", label= "Performance point")

# %%
MP3C1 = ARCHIVO['MP3 C'][1:8]
MP3C2 = ARCHIVO['MP3 C'][9:18]
MP3C3 = ARCHIVO['MP3 C'][19:30]
MP3C4 = ARCHIVO['MP3 C'][31:42]
MP3C5 = ARCHIVO['MP3 C'][43:56]
MP3MR1 = ARCHIVO['MP3 MR'][1:8]
MP3MR2 = ARCHIVO['MP3 MR'][9:18]
MP3MR3 = ARCHIVO['MP3 MR'][19:30]
MP3MR4 = ARCHIVO['MP3 MR'][31:42]
MP3MR5 = ARCHIVO['MP3 MR'][43:56]
MP3MI1 = ARCHIVO['MP3 MI'][1:8]
MP3MI2 = ARCHIVO['MP3 MI'][9:18]
MP3MI3 = ARCHIVO['MP3 MI'][19:30]
MP3MI4 = ARCHIVO['MP3 MI'][31:42]
MP3MI5 = ARCHIVO['MP3 MI'][43:56]
plt.plot(MP3C1, MP3MR1, color = "black", label = "P = 4000 KN")
plt.plot(MP3C1, MP3MI1, color = "black", ls="-." )
plt.plot(MP3C2, MP3MR2, color = "dimgray", label = "P = 2667 KN")
plt.plot(MP3C2, MP3MI2, color = "dimgray", ls="-.")
plt.plot(MP3C3, MP3MR3, color = "gray", label = "P = 1006 KN")
plt.plot(MP3C3, MP3MI3, color = "gray", ls="-.")
plt.plot(MP3C5, MP3MR5, color = "slategrey", label = "P = 321 KN (Service Load)")
plt.plot(MP3C5, MP3MI5, color = "slategrey", ls="-.")
plt.plot(MP3C4, MP3MR4, color = "silver", label = "P = 0 KN")
plt.plot(MP3C4, MP3MI4, color = "silver", ls="-.")

plt.xlim(0)
plt.ylim(0, 5000)
plt.legend(loc='lower right')
plt.xlabel(r'Curvature $[1/mm]$')
plt.ylabel(r'Moment $[kN.m]$')
plt.title(r"Moment-Curvature Diagram in Wall")
plt.savefig(fname="momentocurvaturamuro.pdf", dpi=500, format="pdf")
print(MP3MR5, MP3MI5)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File c:\ProgramData\Anaconda3\lib\site-packages\pandas\core\indexes\base.py:3621, in Index.get_loc(self, key, method, tolerance)
#    3620 try:
# -> 3621     return self._engine.get_loc(casted_key)
#    3622 except KeyError as err:
#
# File c:\ProgramData\Anaconda3\lib\site-packages\pandas\_libs\index.pyx:136, in pandas._libs.index.IndexEngine.get_loc()
#
# File c:\ProgramData\Anaconda3\lib\site-packages\pandas\_libs\index.pyx:163, in pandas._libs.index.IndexEngine.get_loc()
#
# File pandas\_libs\hashtable_class_helper.pxi:5198, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# File pandas\_libs\hashtable_class_helper.pxi:5206, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'MP3 C'
#
# The above exception was the direct cause of the following exception:
#
# ...

# %%
CC18C1 = ARCHIVO['CC18 C'][1:14]
CC18C2 = ARCHIVO['CC18 C'][15:29]
CC18C3 = ARCHIVO['CC18 C'][30:44]
CC18C4 = ARCHIVO['CC18 C'][45:58]
CC18C5 = ARCHIVO['CC18 C'][60:72]

CC18MR1 = ARCHIVO['CC18 MR'][1:14]
CC18MR2 = ARCHIVO['CC18 MR'][15:29]
CC18MR3 = ARCHIVO['CC18 MR'][30:44]
CC18MR4 = ARCHIVO['CC18 MR'][45:58]
CC18MR5 = ARCHIVO['CC18 MR'][60:72]

CC18MI1 = ARCHIVO['CC18 MI'][1:14]
CC18MI2 = ARCHIVO['CC18 MI'][15:29]
CC18MI3 = ARCHIVO['CC18 MI'][30:44]
CC18MI4 = ARCHIVO['CC18 MI'][45:58]
CC18MI5 = ARCHIVO['CC18 MI'][60:72]

allCC18 = ARCHIVO['CC18 MI'][1:80]
plt.plot(CC18C1, CC18MR1, color = "black", label = "P = 3018 KN")
plt.plot(CC18C1, CC18MI1, color = "black", ls="-.")
plt.plot(CC18C2, CC18MR2, color = "dimgray", label = "P = 2012 KN")
plt.plot(CC18C2, CC18MI2, color = "dimgray", ls="-.")
plt.plot(CC18C3, CC18MR3, color = "gray", label = "P = 1005 KN")
plt.plot(CC18C3, CC18MI3, color = "gray", ls="-.")
plt.plot(CC18C4, CC18MR4, color = "slategrey", label = "P = 0 KN")
plt.plot(CC18C4, CC18MI4, color = "slategrey", ls="-.")
plt.plot(CC18C5, CC18MR5, color = "silver", label = "P = Service load")
plt.plot(CC18C5, CC18MI5, color = "silver", ls="-.")

plt.xlim(0)
plt.ylim(0, 500)
plt.legend(loc='lower right')
plt.xlabel(r'Curvature $[1/mm]$')
plt.ylabel(r'Moment $[kN.m]$')
plt.title(r"Moment-Curvature Diagram in Col")
plt.savefig(fname="momentocurvaturamuro.pdf", dpi=500, format="pdf")
print(CC18C5, CC18MR5, CC18MI5)
# Out:
# 60           0
# 61    0.000005
# 62    0.000009
# 63    0.000013
# 64    0.000024
# 65    0.000038
# 66    0.000054
# 67    0.000073
# 68    0.000094
# 69    0.000118
# 70    0.000145
# 71    0.000175
# Name: CC18 C, dtype: object 60             0
# 61      227.2468
# 62    269.914849
# 63      316.1427
# 64      346.9772
# 65      361.4312
# 66      374.8299
# 67      386.0051
# 68      393.5892
# 69      399.9342
# 70       405.967
# 71      409.9546
# Name: CC18 MR, dtype: object 60             0
# 61      227.2468
# 62    390.806216
# 63    390.806216
# 64    390.806216
# 65    390.806216
# 66    390.806216
# 67    390.806216
# 68    390.806216
# 69    390.806216
# 70    390.806216
# 71    390.806216
# Name: CC18 MI, dtype: object
